# %% [markdown]
# # Predicting Bitcoin values with Linear Regression, Decision Tree Regression, and Random Forest Regression Machine Learning

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd  
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Loading necessary models

# %%
models = []
models.append(LinearRegression())
models.append(DecisionTreeRegressor())
models.append(RandomForestRegressor())

# %% [markdown]
# ## Loading and defining our data

# %%
btc_data = pd.read_csv("data/BTC-USD.csv")
X = btc_data[["Open", "High", "Low", "Adj Close", "Volume"]] 
y = btc_data["Close"]

print(btc_data)
# Out:
#            Date          Open  ...     Adj Close        Volume
# 0    2021-01-27  32564.029297  ...  30432.546875   62576762015
# 1    2021-01-28  30441.041016  ...  33466.097656   76517157706
# 2    2021-01-29  34318.671875  ...  34316.386719  117894572511
# 3    2021-01-30  34295.933594  ...  34269.523438   65141828798
# 4    2021-01-31  34270.878906  ...  33114.359375   52754542671
# ..          ...           ...  ...           ...           ...
# 361  2022-01-23  35047.359375  ...  36276.804688   26017975951
# 362  2022-01-24  36275.734375  ...  36654.328125   41856658597
# 363  2022-01-25  36654.804688  ...  36954.003906   26428189594
# 364  2022-01-26  36950.515625  ...  36852.121094   31324598034
# 365  2022-01-27  36781.855469  ...  36006.652344   25060448256
#
# [366 rows x 7 columns]

# %% [markdown]
# ## Splitting data into test and train

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# ## Running each algorithm to get our results

# %%
for m in models:
    clf = m 
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    r2 = r2_score(y_test, y_pred)
    res = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])

    print("-"*80)
    print("Model: " + str(m))
    print(y_pred)
    print("r2: " + str(r2))
    print("MEPR: " + str(mean_absolute_percentage_error(y_test, y_pred)) + "%")
    print("-"*80)
# Out:
# --------------------------------------------------------------------------------
# Model: LinearRegression()
# [61393.61718804 49705.33203095 49199.87109392 38053.50390602
#  47793.32031303 46391.42187501 31421.53906305 59057.87890596
#  56099.51953094 63326.98828105 46707.01562505 35551.95703102
#  40869.55468802 39208.76562502 38402.22265597 37472.08984396
#  58730.47656304 58192.35937495 65992.83593801 57828.050781
#  57539.94531298 48905.49218801 34649.64453102 36852.12109403
#  32186.27734401 42735.85546904 47672.12109403 47243.30468803
#  57603.89062496 37304.69140591 56041.05859401 33897.04687501
#  58758.55468798 65466.83984405 39995.90625001 54021.75390596
#  33155.84765605 34235.19531304 54738.94531297 34434.33593802
#  47096.94531303 33798.01171904 34292.44531305 37337.53515598
#  47105.51562493 33723.02734399 46339.76171824 61318.95703103
#  56048.93749992 59697.19531303 59384.31249996 53906.08984397
#  46063.26953104 34269.52343795 32110.69335904 57248.45703104
#  66971.828125   47054.98437503 57424.00781294 50640.41796905
#  37575.17968803 50429.85937506 62026.07812501 46365.40234401
#  45201.45703102 31780.73046906 48176.34765603 48960.78906303
#  46196.46484386 46481.10546888 57806.56640603 63109.69531292
#  47706.11718802 47093.85156297]
# r2: 1.0
# MEPR: 1.0289027293906276e-12%
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model: DecisionTreeRegressor()
# [61452.230469 49716.191406 49112.902344 38152.980469 47783.359375
#  46456.058594 31796.810547 58918.832031 55973.511719 63314.011719
#  46760.1875   35552.515625 40782.738281 39406.941406 38705.980469
#  37536.632813 59095.808594 58245.003906 64995.230469 57523.421875
#  57523.421875 48896.722656 34662.4375   36926.066406 32313.105469
#  42716.59375  47711.488281 47260.21875  57750.175781 37536.632813
#  55973.511719 33746.003906 58803.777344 64995.230469 40218.476563
#  54207.320313 33114.359375 34240.1875   54815.078125 34240.1875
#  47047.003906 33746.003906 34240.1875   37345.121094 47047.003906
#  33746.003906 46306.445313 61125.675781 55973.511719 59893.453125
#  59095.808594 53967.847656 46091.390625 34240.1875   32313.105469
#  57200.292969 67566.828125 47260.21875  57401.097656 50582.625
#  37334.398438 50504.796875 61888.832031 46306.445313 45137.769531
#  31796.810547 48199.953125 48936.613281 46091.390625 46458.117188
#  57569.074219 63039.824219 47588.855469 47260.21875 ]
# r2: 0.9996187044954303
# MEPR: 0.0025678756717613612%
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model: RandomForestRegressor()
# [61486.6269925  49679.48304693 49204.43351563 38276.23097672
#  47753.73890619 46392.46203161 31569.00746082 58979.85890621
#  56048.13808601 63202.90531267 46741.19949238 35599.63828131
#  40540.87457033 39226.06882823 38385.45953135 37392.48703157
#  58930.58632817 58292.76066386 64750.8950784  57738.41125016
#  57555.96355476 48894.99414073 34586.82765624 36999.58382805
#  32009.91181632 42813.07878919 47688.54917962 47276.9255468
#  57550.77742198 37428.22445339 55962.14093759 33733.12667963
#  58827.76429689 64677.69183619 40025.14242204 53689.93308601
#  33061.74773444 34260.78242187 54805.43714851 34470.83910161
#  47139.39628902 33709.73613269 34299.02601563 37384.52031282
#  47128.54910162 33699.82695301 46285.7477738  61329.04078139
#  55939.42242199 59894.29500009 59219.76843755 53864.40445319
#  45915.48246099 34322.74726563 31784.75992179 57324.64187516
#  66277.63128921 47130.45839843 57477.7008594  50691.2939456
#  37378.78253944 50587.16894544 61884.81335949 46125.85468775
#  45133.99101558 31780.33386713 48187.6364452  48929.23324234
#  45760.90355474 46396.54894566 57728.72484393 63379.90281271
#  47704.53476558 47143.38679691]
# r2: 0.9994917654813534
# MEPR: 0.0025674383397650546%
# --------------------------------------------------------------------------------
