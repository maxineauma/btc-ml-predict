# %% [markdown]
# # Predicting Bitcoin values with Linear Regression, Decision Tree Regression, and Random Forest Regression Machine Learning

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd  
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ## Loading necessary models

# %%
models = []
models.append(LinearRegression())
models.append(DecisionTreeRegressor())
models.append(RandomForestRegressor())

# %% [markdown]
# ## Loading and defining our data

# %%
btc_data = pd.read_csv("data/BTC-USD.csv")
X = btc_data[["Open", "High", "Low", "Adj Close", "Volume"]] 
y = btc_data["Close"]

print(btc_data)
# Out:
#            Date          Open  ...     Adj Close        Volume
# 0    2021-01-27  32564.029297  ...  30432.546875   62576762015
# 1    2021-01-28  30441.041016  ...  33466.097656   76517157706
# 2    2021-01-29  34318.671875  ...  34316.386719  117894572511
# 3    2021-01-30  34295.933594  ...  34269.523438   65141828798
# 4    2021-01-31  34270.878906  ...  33114.359375   52754542671
# ..          ...           ...  ...           ...           ...
# 361  2022-01-23  35047.359375  ...  36276.804688   26017975951
# 362  2022-01-24  36275.734375  ...  36654.328125   41856658597
# 363  2022-01-25  36654.804688  ...  36954.003906   26428189594
# 364  2022-01-26  36950.515625  ...  36852.121094   31324598034
# 365  2022-01-27  36781.855469  ...  36006.652344   25060448256
#
# [366 rows x 7 columns]

# %% [markdown]
# ## Splitting data into test and train

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# ## Running each algorithm to get our results

# %%
for m in models:
    clf = m 
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    r2 = r2_score(y_test, y_pred)
    res = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])

    print("-"*80)
    print("Model: " + str(m))
    print(y_pred)
    print("r2: " + str(r2))
    print("MER: " + str(mean_absolute_percentage_error(y_test, y_pred)))
    print("-"*80)
# Out:
# --------------------------------------------------------------------------------
# Model: LinearRegression()
# [61393.61718804 49705.33203095 49199.87109392 38053.50390602
#  47793.32031303 46391.42187501 31421.53906305 59057.87890596
#  56099.51953094 63326.98828105 46707.01562505 35551.95703102
#  40869.55468802 39208.76562502 38402.22265597 37472.08984396
#  58730.47656304 58192.35937495 65992.83593801 57828.050781
#  57539.94531298 48905.49218801 34649.64453102 36852.12109403
#  32186.27734401 42735.85546904 47672.12109403 47243.30468803
#  57603.89062496 37304.69140591 56041.05859401 33897.04687501
#  58758.55468798 65466.83984405 39995.90625001 54021.75390596
#  33155.84765605 34235.19531304 54738.94531297 34434.33593802
#  47096.94531303 33798.01171904 34292.44531305 37337.53515598
#  47105.51562493 33723.02734399 46339.76171824 61318.95703103
#  56048.93749992 59697.19531303 59384.31249996 53906.08984397
#  46063.26953104 34269.52343795 32110.69335904 57248.45703104
#  66971.828125   47054.98437503 57424.00781294 50640.41796905
#  37575.17968803 50429.85937506 62026.07812501 46365.40234401
#  45201.45703102 31780.73046906 48176.34765603 48960.78906303
#  46196.46484386 46481.10546888 57806.56640603 63109.69531292
#  47706.11718802 47093.85156297]
# r2: 1.0
# MER: 1.0289027293906276e-12
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model: DecisionTreeRegressor()
# [61452.230469 49716.191406 49112.902344 38144.308594 47783.359375
#  46458.117188 31533.068359 59095.808594 55907.199219 63314.011719
#  46760.1875   35552.515625 40782.738281 39406.941406 38436.96875
#  37345.121094 58803.777344 58232.316406 64261.992188 57805.121094
#  57523.421875 48896.722656 34662.4375   36894.40625  32313.105469
#  42716.59375  47665.425781 47345.21875  57523.421875 37536.632813
#  55950.746094 33855.328125 58803.777344 64469.527344 40008.421875
#  53967.847656 33114.359375 34240.1875   54815.078125 34316.386719
#  47267.519531 33746.003906 34240.1875   37536.632813 47345.21875
#  33746.003906 46306.445313 61125.675781 55907.199219 59893.453125
#  59095.808594 53967.847656 46091.390625 34316.386719 32313.105469
#  57229.828125 67566.828125 47260.21875  57401.097656 50582.625
#  37536.632813 50504.796875 62210.171875 46306.445313 45593.636719
#  31533.068359 48278.363281 48927.304688 46202.144531 46456.058594
#  57805.121094 63039.824219 47711.488281 47260.21875 ]
# r2: 0.9992953626296213
# MER: 0.0025266410077586657
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Model: RandomForestRegressor()
# [61499.56863313 49698.0564454  49181.03636719 38208.753008
#  47761.51499993 46340.73800815 31547.54996075 58994.53917968
#  56051.40906252 63090.9503908  46728.54078144 35578.68972666
#  40472.75871097 39235.3438282  38288.02863295 37415.28515662
#  58926.61742192 58311.98312482 64789.18589871 57740.03164074
#  57530.24402358 48893.06417981 34596.47726563 36977.31374986
#  32061.90166008 42820.72062511 47687.3236718  47276.76523432
#  57556.68082044 37407.0515628  55985.57347661 33690.50878904
#  58786.35386719 64691.59351587 39986.01890641 53573.32398448
#  33092.05560555 34289.59886718 54792.42429698 34486.16410164
#  47125.26175778 33691.30242174 34340.66457033 37385.84601598
#  47123.64402348 33674.87880852 46241.63812534 61322.31050797
#  55950.53691414 59873.13644539 59200.63382819 53838.13695321
#  45813.28292972 34323.55628908 31876.53343744 57324.93960951
#  66199.41339861 47111.8247265  57465.65949226 50684.6433206
#  37388.01640666 50615.86121112 61897.83558605 45913.2344924
#  45169.51808593 31701.16134757 48169.81156238 48917.68234385
#  45333.01367187 46421.94117222 57745.25214857 63317.10972674
#  47693.13238282 47134.03792974]
# r2: 0.999384812333984
# MER: 0.002815760663877255
# --------------------------------------------------------------------------------
